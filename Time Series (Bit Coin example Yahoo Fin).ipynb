# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
bitcoin=pd.read_csv(r'C:\Users\Administrateur\Downloads\BTC-EUR.csv')

# %%
bitcoin
# Out:
#             Date          Open          High           Low         Close  \
# 0     2014-09-17    359.546204    361.468506    351.586884    355.957367
# 1     2014-09-18    355.588409    355.505402    319.789459    328.539368
# 2     2014-09-19    328.278503    330.936707    298.921021    307.761139
# 3     2014-09-20    307.665253    329.978180    303.931244    318.758972
# 4     2014-09-21    318.120514    321.504517    306.502197    310.632446
# ...          ...           ...           ...           ...           ...
# 2224  2020-10-19   9810.681641  10009.772461   9745.417969   9977.561523
# 2225  2020-10-20   9980.907227  10141.070313   9923.708984  10073.855469
# 2226  2020-10-21  10071.101563  11117.054688  10060.009766  10820.051758
# 2227  2020-10-22  10801.443359  11132.668945  10736.342773  10973.163086
# 2228  2020-10-23  10973.875977  11006.295898  10897.520508  10927.057617
#
#          Adj Close        Volume
# 0       355.957367  1.638916e+07
# ...

# %%
bitcoin['Close'].plot()
# Out:
# <AxesSubplot:>

# %%
bitcoin=pd.read_csv(r'C:\Users\Administrateur\Downloads\BTC-EUR.csv', index_col = 'Date')

# %% [markdown]
# l'axe des X va recevoir les dates

# %%
bitcoin['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# parse = true indique à Pandas qu'il s'agit de dates

# %%
bitcoin=pd.read_csv(r'C:\Users\Administrateur\Downloads\BTC-EUR.csv', index_col = 'Date', parse_dates = True)

# %%
bitcoin.head(5)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-17  359.546204  361.468506  351.586884  355.957367  355.957367
# 2014-09-18  355.588409  355.505402  319.789459  328.539368  328.539368
# 2014-09-19  328.278503  330.936707  298.921021  307.761139  307.761139
# 2014-09-20  307.665253  329.978180  303.931244  318.758972  318.758972
# 2014-09-21  318.120514  321.504517  306.502197  310.632446  310.632446
#
#                 Volume
# Date
# 2014-09-17  16389165.0
# 2014-09-18  26691849.0
# 2014-09-19  29560102.0
# 2014-09-20  28736825.0
# 2014-09-21  20702624.0

# %%
bitcoin.index
# Out:
# DatetimeIndex(['2014-09-17', '2014-09-18', '2014-09-19', '2014-09-20',
#                '2014-09-21', '2014-09-22', '2014-09-23', '2014-09-24',
#                '2014-09-25', '2014-09-26',
#                ...
#                '2020-10-14', '2020-10-15', '2020-10-16', '2020-10-17',
#                '2020-10-18', '2020-10-19', '2020-10-20', '2020-10-21',
#                '2020-10-22', '2020-10-23'],
#               dtype='datetime64[ns]', name='Date', length=2229, freq=None)

# %% [markdown]
# il s'agit bien de dates

# %%
bitcoin['2019']['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# pour voir sept 2019

# %%
bitcoin['2019-09']['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# slicing entre dates

# %%
bitcoin['2017':'2019']['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bitcoin.loc['2019':'2020','Close'].resample('M').plot()
# Out:
# Date
# 2019-01-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-02-28    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-03-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-04-30    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-05-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-06-30    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-07-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-08-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-09-30    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-10-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-11-30    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019-12-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2020-01-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2020-02-29    AxesSubplot(0.125,0.125;0.775x0.755)
# 2020-03-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2020-04-30    AxesSubplot(0.125,0.125;0.775x0.755)
# 2020-05-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2020-06-30    AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %% [markdown]
# pour la moyenne mensuelle

# %%
bitcoin.loc['2019':'2020','Close'].resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# volatilité 2 weeks

# %%
bitcoin.loc['2019':'2020','Close'].resample('2W').std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#plt.figure(figsize(12,8))
bitcoin.loc['2019','Close'].plot()
bitcoin.loc['2019','Close'].resample('M').mean().plot(label= 'Moyenne par mois', lw=3, ls=':', alpha=0.8)
bitcoin.loc['2019','Close'].resample('W').mean().plot(label= 'Moyenne par semaine', lw=2, ls='--', alpha=0.8)
plt.legend()
plt.show()

# %%
bitcoin.loc['2019','Close'].resample('W').agg(['mean', 'std', 'min', 'max']).head(8)
# Out:
#                    mean         std          min          max
# Date
# 2019-01-06  3422.916626   86.768296  3353.505859  3572.601807
# 2019-01-13  3317.593401  180.066248  3100.221680  3518.607910
# 2019-01-20  3216.173340   36.646566  3168.373535  3280.021484
# 2019-01-27  3157.861154   15.218334  3140.374756  3183.176025
# 2019-02-03  3035.448347   19.472269  3015.454102  3073.150146
# 2019-02-10  3114.468541  123.483779  2998.157227  3258.583740
# 2019-02-17  3222.201835   17.498269  3202.042725  3252.190186
# 2019-02-24  3500.129360   88.628342  3359.558594  3653.833008

# %%
bitcoin.loc['2019','Close'].resample('W').agg(['mean', 'std', 'min', 'max']).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
m=bitcoin['Close'].resample('W').agg(['mean', 'std', 'min', 'max'])

plt.figure(figsize=(12,8))
m['mean']['2019'].plot(label= 'moyenne par semaine')
plt.fill_between(m.index, m['max'], m['min'], alpha=0.2, label= 'min - max par semaine')

plt.legend()
plt.show()
