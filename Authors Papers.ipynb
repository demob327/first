# %%
! python -V
# Out:
# Python 3.11.4

# %%
# scipy
import scipy
print('scipy: %s' % scipy.__version__)
# numpy
import numpy
print('numpy: %s' % numpy.__version__)
# matplotlib
import matplotlib
print('matplotlib: %s' % matplotlib.__version__)
# pandas
import pandas
print('pandas: %s' % pandas.__version__)
# statsmodels
import statsmodels
print('statsmodels: %s' % statsmodels.__version__)
# scikit-learn
import sklearn
print('sklearn: %s' % sklearn.__version__)
# Out:
# scipy: 1.11.1
# numpy: 1.25.1
# matplotlib: 3.7.2
# pandas: 2.0.3
# statsmodels: 0.14.0
# sklearn: 1.3.0

# %%
! pip install theano
# Out:
# ...
#                                               0.0/2.8 MB ? eta -:--:--
#                                               0.0/2.8 MB ? eta -:--:--
#                                               0.0/2.8 MB ? eta -:--:--
#                                               0.0/2.8 MB 325.1 kB/s eta 0:00:09
#                                               0.0/2.8 MB 325.1 kB/s eta 0:00:09
#                                               0.0/2.8 MB 245.8 kB/s eta 0:00:12
#                                               0.0/2.8 MB 245.8 kB/s eta 0:00:12
#                                               0.1/2.8 MB 252.2 kB/s eta 0:00:12
#                                               0.1/2.8 MB 252.2 kB/s eta 0:00:12
#      -                                        0.1/2.8 MB 254.2 kB/s eta 0:00:11
#      -                                        0.1/2.8 MB 238.1 kB/s eta 0:00:12
#      -                                        0.1/2.8 MB 242.7 kB/s eta 0:00:12
# ...

# %%
! pip install keras
# Out:
# ...
#                                               0.0/1.7 MB ? eta -:--:--
#                                               0.0/1.7 MB ? eta -:--:--
#                                               0.0/1.7 MB ? eta -:--:--
#                                               0.0/1.7 MB ? eta -:--:--
#                                               0.0/1.7 MB 217.9 kB/s eta 0:00:08
#                                               0.0/1.7 MB 196.9 kB/s eta 0:00:09
#                                               0.0/1.7 MB 196.9 kB/s eta 0:00:09
#      -                                        0.1/1.7 MB 233.8 kB/s eta 0:00:08
#      -                                        0.1/1.7 MB 233.8 kB/s eta 0:00:08
#      -                                        0.1/1.7 MB 206.9 kB/s eta 0:00:08
#      --                                       0.1/1.7 MB 218.5 kB/s eta 0:00:08
#      --                                       0.1/1.7 MB 218.5 kB/s eta 0:00:08
# ...

# %%
import pandas as pd
df_authors = pd.read_excel(r'C:\Users\Administrateur\Documents\authors.xlsx')

# %%
df_authors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      750 non-null    int64
#  1   name    750 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 11.8+ KB

# %%
df_papers = pd.read_excel(r'C:\Users\Administrateur\Documents\papers.xlsx')

# %%
df_papers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8905 entries, 0 to 8904
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Conference   8905 non-null   object
#  1   Year         8905 non-null   int64
#  2   Title        8905 non-null   object
#  3   Author       8905 non-null   object
#  4   Affiliation  8561 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 348.0+ KB

# %%
df_papers['Title'].unique()
# Out:
# array(['Decoupled Neural Interfaces using Synthetic Gradients',
#        'PixelCNN Models with Auxiliary Variables for Natural Image Modeling',
#        'Tight Bounds for Approximate Carathéodory and Beyond', ...,
#        'Toward Provably Correct Feature Selection in Arbitrary Domains',
#        'Bayesian estimation of orientation preference maps',
#        'Matrix Completion from Power-Law Distributed Samples'],
#       dtype=object)

# %%
x = df_papers[df_papers['Affiliation'] == 'non-null']

# %%
x.shape
# Out:
# (0, 5)

# %%
x
# Out:
# Empty DataFrame
# Columns: [Conference, Year, Title, Author, Affiliation]
# Index: []
