# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r'Z:\cotMoyDZ.xlsx', index_col = 'Date', parse_dates = True )
df.sample(7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_excel(r'Z:\cotMoyDZ.xlsx', index_col = 'Date', parse_dates = True )
#       2 df.sample(7)
#
# File c:\Users\Administrateur\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:486, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#     485 try:
# --> 486     data = io.parse(
#     487         sheet_name=sheet_name,
# ...

# %%
df = df.drop(['Dinar'], axis=1)

# %%
df.sample(7)
# Out:
#                  Taux Devise
# Date
# 2020-10-20  166.94000    GBP
# 2020-07-28  127.91229    USD
# 2020-09-30  129.15316    USD
# 2020-06-11  145.13790    EUR
# 2020-05-14  157.48000    GBP
# 2020-10-07  166.39000    GBP
# 2020-09-08  167.22000    GBP

# %%
usd = df[df['Devise'] =='USD']

# %%
eur = df[df['Devise'] =='EUR']

# %%
gbp = df[df['Devise'] =='GBP']

# %%
df1 = df.groupby('Devise')
df1.head()
# Out:
#                  Taux Devise
# Date
# 2020-04-29  139.47000    EUR
# 2020-04-30  140.05600    EUR
# 2020-05-01  141.84400    EUR
# 2020-05-04  140.25250    EUR
# 2020-05-05  139.86010    EUR
# 2020-04-29  160.00000    GBP
# 2020-04-30  161.03000    GBP
# 2020-05-01  161.55000    GBP
# 2020-05-04  160.00000    GBP
# 2020-05-05  160.51000    GBP
# 2020-04-29  128.22324    USD
# 2020-04-30  127.82851    USD
# 2020-05-01  129.22176    USD
# 2020-05-04  128.58728    USD
# 2020-05-05  128.93915    USD

# %%
df1.plot()
# Out:
# Devise
# EUR    Axes(0.125,0.11;0.775x0.77)
# GBP    Axes(0.125,0.11;0.775x0.77)
# USD     Axes(0.125,0.2;0.775x0.68)
# dtype: object
